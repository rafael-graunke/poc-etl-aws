# %% [markdown]
# ## Exibindo dados tratados

# %% [markdown]
# ### Agrupando arquivos particionados em unico DataFrame

# %%
import glob
import pandas as pd

files = glob.glob("output/*")
dfs = [pd.read_csv(f) for f in files]

df = pd.concat(dfs, ignore_index=True)

# %%
df.sort_values("postId")
# Out:
#     postId  count_mensagens  \
# 13       1                5
# 70       2                5
# 14       3                5
# 28       4                5
# 60       5                5
# ..     ...              ...
# 42      96                5
# 99      97                5
# 59      98                5
# 84      99                5
# 55     100                5
#
#                                       ultima_mensagem          username
# 13  harum non quasi et ratione\ntempore iure ex vo...            Eliseo
# 70  voluptate iusto quis nobis reprehenderit ipsum...   Presley.Mueller
# 14  nihil ut voluptates blanditiis autem odio dict...  Veronica_Goodwin
# 28  qui harum consequatur fugiat\net eligendi perf...         Christine
# 60  sunt aut quae laboriosam sit ut impedit\nadipi...            Noemie
# ..                                                ...               ...
# 42  tenetur qui ut\narchitecto officiis voluptatem...       Amely.Kunde
# ...
